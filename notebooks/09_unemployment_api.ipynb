# %%
import numpy as np
import pandas as pd
import requests

# %%
url = 'https://api.worldbank.org/v2/country/all/indicator/SL.UEM.TOTL.ZS?format=json&per_page=20000'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 20000,
#   'total': 17490,
#   'sourceid': '2',
#   'lastupdated': '2026-07-01'},
#  [{'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2025',
#    'value': 7.53923324035891,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2024',
#    'value': 7.57169749274654,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2023',
#    'value': 7.67654773372157,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2022',
#    'value': 7.86947018999245,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2021',
#    'value': 8.40741154700022,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2020',
#    'value': 7.97430164130982,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2019',
#    'value': 7.45910636823544,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2018',
#    'value': 7.24484282680541,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2017',
#    'value': 7.21491501896869,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2016',
#    'value': 7.07442880999326,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2015',
#    'value': 6.9309412585873,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2014',
#    'value': 6.86242857576034,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2013',
#    'value': 6.88972223038428,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2012',
#    'value': 7.10873740350119,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2011',
#    'value': 7.303350943492,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2010',
#    'value': 7.33948885318777,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2009',
#    'value': 7.02933493362019,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2008',
#    'value': 6.95926232871186,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2007',
#    'value': 6.98058891496815,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2006',
#    'value': 7.03560059961336,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2005',
#    'value': 7.10041371887931,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2004',
#    'value': 7.27852246959678,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2003',
#    'value': 7.4720424200925,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2002',
#    'value': 7.51149338877195,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2001',
#    'value': 7.55388452430262,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2000',
#    'value': 7.66876829683373,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1999',
#    'value': 7.72993010885893,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1998',
#    'value': 7.68263780767572,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1997',
#    'value': 7.64190636706094,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1996',
#    'value': 7.6816226939442,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1995',
#    'value': 7.77389399169686,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1994',
#    'value': 8.02210049864685,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1993',
#    'value': 8.15590989808314,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1992',
#    'value': 8.15827337351447,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1991',
#    'value': 8.05080898877577,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1990',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1989',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1988',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1987',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1986',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1985',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1984',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1983',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1982',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1981',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1980',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1979',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1978',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1977',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1976',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1975',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1974',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1973',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1972',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1971',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1970',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1969',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1968',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1967',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1966',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1965',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1964',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1963',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1962',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1961',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1960',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2025',
#    'value': 3.19297271435272,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2024',
#    'value': 3.17491538811068,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2023',
#    'value': 3.20335496340002,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2022',
#    'value': 3.59653801462938,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2021',
#    'value': 4.67076109003218,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2020',
#    'value': 4.7993062016358,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2019',
#    'value': 4.39390284484525,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2018',
#    'value': 4.33609979249296,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2017',
#    'value': 4.28464574730964,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2016',
#    'value': 4.16910166908106,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2015',
#    'value': 4.1727731083969,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2014',
#    'value': 3.89018286622866,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2013',
#    'value': 3.71010995935874,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2012',
#    'value': 3.98291438560293,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2011',
#    'value': 3.97007365881551,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2010',
#    'value': 3.99179170645225,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2009',
#    'value': 4.00441257217998,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2008',
#    'value': 3.96808904592347,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2007',
#    'value': 3.94820495192994,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2006',
#    'value': 3.96900207619704,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2005',
#    'value': 4.09641162927698,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2004',
#    'value': 4.08698904128015,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2003',
#    'value': 4.1682062921006,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2002',
#    'value': 4.27392083907488,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2001',
#    'value': 4.46563029423928,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2000',
#    'value': 4.53131047835059,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1999',
#    'value': 4.49044730082985,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1998',
#    'value': 4.30483459729659,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1997',
#    'value': 4.29679829052344,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1996',
#    'value': 4.32685070034471,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1995',
#    'value': 4.39327114704215,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1994',
#    'value': 4.39040299907666,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1993',
#    'value': 4.36682360679359,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1992',
#    'value': 4.24675578183281,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1991',
#    'value': 4.15800759981861,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1990',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1989',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1988',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1987',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1986',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1985',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1984',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1983',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1982',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1981',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1980',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1979',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1978',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1977',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1976',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1975',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1974',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1973',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1972',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1971',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1970',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1969',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1968',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1967',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1966',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1965',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1964',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1963',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1962',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1961',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1960',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2025',
#    'value': 9.19017299614363,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2024',
#    'value': 9.26592419265215,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2023',
#    'value': 9.31338863204988,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2022',
#    'value': 9.74413095599936,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2021',
#    'value': 10.8627489086684,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2020',
#    'value': 11.2951503646669,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2019',
#    'value': 10.2137182910936,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2018',
#    'value': 10.6546406452031,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2017',
#    'value': 11.1152019032057,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2016',
#    'value': 10.8617161429412,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2015',
#    'value': 11.1524464292006,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2014',
#    'value': 11.0319261608507,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2013',
#    'value': 11.0350018909533,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2012',
#    'value': 11.0650966632009,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2011',
#    'value': 10.6873951414609,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2010',
#    'value': 9.57178825247491,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2009',
#    'value': 9.46079216862091,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2008',
#    'value': 9.87515901443002,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
# ...
#    'countryiso3code': 'HPC',
#    'date': '1999',
#    'value': 5.09795696108793,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1998',
#    'value': 4.95315415735027,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1997',
#    'value': 4.88719727776726,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1996',
#    'value': 4.95292940806701,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1995',
#    'value': 4.98419036566327,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1994',
#    'value': 5.16826884648105,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1993',
#    'value': 5.22675203435376,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1992',
#    'value': 5.23141741602695,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1991',
#    'value': 5.1214478571728,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1990',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1989',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1988',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1987',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1986',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1985',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1984',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1983',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1982',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1981',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1980',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1979',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1978',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1977',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1976',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1975',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1974',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1973',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1972',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1971',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1970',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1969',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1968',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1967',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1966',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1965',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1964',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1963',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1962',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1961',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1960',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2025',
#    'value': 4.40673460951033,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2024',
#    'value': 4.36900295139978,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2023',
#    'value': 4.33657934041449,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2022',
#    'value': 4.50967974234969,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2021',
#    'value': 5.56341269080663,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2020',
#    'value': 6.46030036409899,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2019',
#    'value': 4.76095962548232,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2018',
#    'value': 5.0794494069113,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2017',
#    'value': 5.57808653810898,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#     'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2016',
#    'value': 6.11023166310052,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   ...]]

# %%
data[0]
# Out:
# {'page': 1,
#  'pages': 1,
#  'per_page': 20000,
#  'total': 17490,
#  'sourceid': '2',
#  'lastupdated': '2026-07-01'}

# %%
data[1][0]
# Out:
# {'indicator': {'id': 'SL.UEM.TOTL.ZS',
#   'value': 'Unemployment, total (% of total labor force) (modeled ILO estimate)'},
#  'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#  'countryiso3code': 'AFE',
#  'date': '2025',
#  'value': 7.53923324035891,
#  'unit': '',
#  'obs_status': '',
#  'decimal': 1}

# %%
records = data[1]

# %%
df = pd.DataFrame(records)

# %%
df.shape
# Out:
# (17490, 8)

# %%
df.columns
# Out:
# Index(['indicator', 'country', 'countryiso3code', 'date', 'value', 'unit',
#        'obs_status', 'decimal'],
#       dtype='object')

# %%
df = df[['country', 'countryiso3code', 'date', 'value']]

# %% [markdown]
# # Data Cleaning

# %%
df['country'] = df['country'].apply(lambda x : x['value'])

# %%
df.head()
# Out:
#                        country countryiso3code  date     value
# 0  Africa Eastern and Southern             AFE  2025  7.539233
# 1  Africa Eastern and Southern             AFE  2024  7.571697
# 2  Africa Eastern and Southern             AFE  2023  7.676548
# 3  Africa Eastern and Southern             AFE  2022  7.869470
# 4  Africa Eastern and Southern             AFE  2021  8.407412
