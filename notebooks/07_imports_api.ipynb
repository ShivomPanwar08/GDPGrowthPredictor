# %%
import numpy as np
import pandas as pd
import requests

# %%
url = 'https://api.worldbank.org/v2/country/all/indicator/NE.IMP.GNFS.ZS?format=json&per_page=20000'

# %%
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
data = response.json()

# %%
type(data)
# Out:
# list

# %%
data
# Out:
# [{'page': 1,
#   'pages': 1,
#   'per_page': 20000,
#   'total': 17490,
#   'sourceid': '2',
#   'lastupdated': '2026-07-01'},
#  [{'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2025',
#    'value': 27.7853990968836,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2024',
#    'value': 28.3057372919042,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2023',
#    'value': 29.503506685176,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2022',
#    'value': 29.4724601086904,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2021',
#    'value': 26.2881671327756,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2020',
#    'value': 24.2926049272612,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2019',
#    'value': 27.2160149136586,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2018',
#    'value': 28.4028082334318,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2017',
#    'value': 27.4060390362816,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2016',
#    'value': 28.6800694143067,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2015',
#    'value': 30.7145156933407,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2014',
#    'value': 32.9761017814553,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2013',
#    'value': 33.7082079879031,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2012',
#    'value': 32.6287820033807,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2011',
#    'value': 31.6686339451965,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2010',
#    'value': 29.4797512451776,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2009',
#    'value': 30.693455177231,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2008',
#    'value': 35.3087960585733,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2007',
#    'value': 31.2924480941032,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2006',
#    'value': 29.0338044245994,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2005',
#    'value': 27.8066358959493,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2004',
#    'value': 26.7112933780207,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2003',
#    'value': 26.0115775877922,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2002',
#    'value': 27.4190699859071,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2001',
#    'value': 26.549361204311,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '2000',
#    'value': 25.839358809097,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1999',
#    'value': 25.6841226438638,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1998',
#    'value': 27.191939711821,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1997',
#    'value': 26.0584701622431,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1996',
#    'value': 26.4178133544527,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1995',
#    'value': 25.8777138625327,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1994',
#    'value': 24.0321567169117,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1993',
#    'value': 21.1983406522708,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1992',
#    'value': 21.0555833586769,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1991',
#    'value': 19.4652389191039,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1990',
#    'value': 19.6424270853207,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1989',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1988',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1987',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1986',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1985',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1984',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1983',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1982',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1981',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1980',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1979',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1978',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1977',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1976',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1975',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1974',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1973',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1972',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1971',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1970',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1969',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1968',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1967',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1966',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1965',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1964',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1963',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1962',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1961',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#    'countryiso3code': 'AFE',
#    'date': '1960',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2025',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2024',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2023',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2022',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2021',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2020',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2019',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2018',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2017',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2016',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2015',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2014',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2013',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2012',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2011',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2010',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2009',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2008',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2007',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2006',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2005',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2004',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2003',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2002',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2001',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '2000',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1999',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1998',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1997',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1996',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1995',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1994',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1993',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1992',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1991',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1990',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1989',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1988',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1987',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1986',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1985',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1984',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1983',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1982',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1981',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1980',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1979',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1978',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1977',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1976',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1975',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1974',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1973',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1972',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1971',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1970',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1969',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1968',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1967',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1966',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1965',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1964',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1963',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1962',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1961',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'ZI', 'value': 'Africa Western and Central'},
#    'countryiso3code': 'AFW',
#    'date': '1960',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2025',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2024',
#    'value': 42.7332163905963,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2023',
#    'value': 40.4664565670022,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2022',
#    'value': 35.9635478046444,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2021',
#    'value': 35.6897534112032,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2020',
#    'value': 36.8407576617223,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2019',
#    'value': 37.1954514662867,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2018',
#    'value': 36.349602375831,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2017',
#    'value': 38.7310021363595,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2016',
#    'value': 38.0585247804958,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2015',
#    'value': 40.4586151480363,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2014',
#    'value': 38.1994364180636,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2013',
#    'value': 36.9485091100388,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2012',
#    'value': 35.8440743120109,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2011',
#    'value': 35.168545886976,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2010',
#    'value': 36.6457500907283,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2009',
#    'value': 41.7205741397958,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2008',
#    'value': 40.1516314141199,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2007',
#    'value': 39.3733054354954,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2006',
#    'value': 35.010791882866,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2005',
#    'value': 35.1045163982062,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2004',
#    'value': 35.1174815535578,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2003',
#    'value': 32.5563669451303,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2002',
#    'value': 31.6741679310603,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2001',
#    'value': 30.7784814547443,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '2000',
#    'value': 29.9197999032517,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1999',
#    'value': 31.3250342573811,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1998',
#    'value': 33.439873197316,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1997',
#    'value': 31.8884331874564,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1996',
#    'value': 32.0518543153173,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1995',
#    'value': 33.612876557051,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1994',
#    'value': 32.8815092292551,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1993',
#    'value': 37.0528087720545,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': '1A', 'value': 'Arab World'},
#    'countryiso3code': 'ARB',
#    'date': '1992',
#    'value': 37.8451698238768,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
# ...
#    'countryiso3code': 'HPC',
#    'date': '2003',
#    'value': 30.5165726986269,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2002',
#    'value': 29.9323778463528,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2001',
#    'value': 28.9730063503281,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '2000',
#    'value': 28.2984726383572,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1999',
#    'value': 29.8185129351489,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1998',
#    'value': 29.6137589770412,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1997',
#    'value': 28.4369887351628,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1996',
#    'value': 28.9952662634783,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1995',
#    'value': 29.0305683480557,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1994',
#    'value': 28.6128906633697,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1993',
#    'value': 24.2644400287504,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1992',
#    'value': 25.5146231994993,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1991',
#    'value': 21.8352609188564,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1990',
#    'value': 21.4043781704747,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1989',
#    'value': 22.619045156602,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1988',
#    'value': 23.3443888371242,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1987',
#    'value': 24.2274349381308,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1986',
#    'value': 23.3296557614868,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1985',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1984',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1983',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1982',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1981',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1980',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1979',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1978',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1977',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1976',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1975',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1974',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1973',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1972',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1971',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1970',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1969',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1968',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1967',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1966',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1965',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1964',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1963',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1962',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1961',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XE', 'value': 'Heavily indebted poor countries (HIPC)'},
#    'countryiso3code': 'HPC',
#    'date': '1960',
#    'value': None,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2025',
#    'value': 30.8167928694479,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2024',
#    'value': 30.2124572959212,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2023',
#    'value': 30.7380890832287,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2022',
#    'value': 32.7455730607901,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2021',
#    'value': 29.875615938147,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2020',
#    'value': 27.6172607767686,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2019',
#    'value': 29.772407084126,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2018',
#    'value': 30.3396707872423,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2017',
#    'value': 29.5428994144556,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#     'value': 'Imports of goods and services (% of GDP)'},
#    'country': {'id': 'XD', 'value': 'High income'},
#    'countryiso3code': '',
#    'date': '2016',
#    'value': 28.4724699040992,
#    'unit': '',
#    'obs_status': '',
#    'decimal': 1},
#   ...]]

# %%
data[0]
# Out:
# {'page': 1,
#  'pages': 1,
#  'per_page': 20000,
#  'total': 17490,
#  'sourceid': '2',
#  'lastupdated': '2026-07-01'}

# %%
data[1][0]
# Out:
# {'indicator': {'id': 'NE.IMP.GNFS.ZS',
#   'value': 'Imports of goods and services (% of GDP)'},
#  'country': {'id': 'ZH', 'value': 'Africa Eastern and Southern'},
#  'countryiso3code': 'AFE',
#  'date': '2025',
#  'value': 27.7853990968836,
#  'unit': '',
#  'obs_status': '',
#  'decimal': 1}

# %%
records = data[1]

# %%
df = pd.DataFrame(records)

# %%
df.head()
# Out:
#                                            indicator  \
# 0  {'id': 'NE.IMP.GNFS.ZS', 'value': 'Imports of ...
# 1  {'id': 'NE.IMP.GNFS.ZS', 'value': 'Imports of ...
# 2  {'id': 'NE.IMP.GNFS.ZS', 'value': 'Imports of ...
# 3  {'id': 'NE.IMP.GNFS.ZS', 'value': 'Imports of ...
# 4  {'id': 'NE.IMP.GNFS.ZS', 'value': 'Imports of ...
#
#                                              country countryiso3code  date  \
# 0  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2025
# 1  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2024
# 2  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2023
# 3  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2022
# 4  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2021
#
#        value unit obs_status  decimal
# 0  27.785399                        1
# 1  28.305737                        1
# 2  29.503507                        1
# 3  29.472460                        1
# 4  26.288167                        1

# %% [markdown]
# # Data Cleaning

# %%
df.shape
# Out:
# (17490, 8)

# %%
df.columns
# Out:
# Index(['indicator', 'country', 'countryiso3code', 'date', 'value', 'unit',
#        'obs_status', 'decimal'],
#       dtype='object')

# %%
df = df[['country', 'countryiso3code', 'date', 'value']]

# %%
df.head()
# Out:
#                                              country countryiso3code  date  \
# 0  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2025
# 1  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2024
# 2  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2023
# 3  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2022
# 4  {'id': 'ZH', 'value': 'Africa Eastern and Sout...             AFE  2021
#
#        value
# 0  27.785399
# 1  28.305737
# 2  29.503507
# 3  29.472460
# 4  26.288167

# %%
df['country'] = df['country'].apply(lambda x : x['value'])

# %%
df.head()
# Out:
#                        country countryiso3code  date      value
# 0  Africa Eastern and Southern             AFE  2025  27.785399
# 1  Africa Eastern and Southern             AFE  2024  28.305737
# 2  Africa Eastern and Southern             AFE  2023  29.503507
# 3  Africa Eastern and Southern             AFE  2022  29.472460
# 4  Africa Eastern and Southern             AFE  2021  26.288167

# %%
df.isnull().sum()
# Out:
# country               0
# countryiso3code       0
# date                  0
# value              6048
# dtype: int64

# %%
df.to_csv('imports.csv', index = False)
